# %% [markdown]
# Lista

# %% [markdown]
# Ex.: frutas = [item1, item2]

# %%
frutas = ['Banana', 'Maçã', 'Uva'] #Lista de frutas.

# %% [markdown]
# estado1 = 'Rio de Janeiro'; estado2 = 'São Paulo'; estado3 = 'Paraíba'; etc.

# %% [markdown]
# Ficaria inviável criar várias variáveis para armazenar as 27 unidades da federação.

# %% [markdown]
# Logo, em Python criasse uma lista contendo os 26 Estados Brasileiros e o Distrito Federal:

# %%
lista_federacao = [

'AAcre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito Federal', 'Espírito Santo', 'Goiás', 'Maranhão', 
'Mato Grosso', 'Mato Grosso do Sul', 'Minas Gerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio de Janeiro',
'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondônia', 'Roraima', 'Santa Catarina', 'São Paulo', 'Sergipe', 'Tocantins'

]

print(lista_federacao)
# Out:
# ['AAcre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito Federal', 'Espírito Santo', 'Goiás', 'Maranhão', 'Mato Grosso', 'Mato Grosso do Sul', 'Minas Gerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio de Janeiro', 'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondônia', 'Roraima', 'Santa Catarina', 'São Paulo', 'Sergipe', 'Tocantins']

# %% [markdown]
# Os indices da lista em Python começa com o 0 (zero):

# %%
print(lista_federacao[0])
# Out:
# Acre

# %%
print(lista_federacao[5])
# Out:
# Ceará

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(lista_federacao[-1])
# Out:
# Tocantins

# %%
print(lista_federacao[-2])
# Out:
# Sergipe

# %%
lista_federacao[0] = 'Acre' #Corrigindo o nome do estado do Acre, que estava com um "A" a mais.

# %%
print(lista_federacao)
# Out:
# ['Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito Federal', 'Espírito Santo', 'Goiás', 'Maranhão', 'Mato Grosso', 'Mato Grosso do Sul', 'Minas Gerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio de Janeiro', 'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondônia', 'Roraima', 'Santa Catarina', 'São Paulo', 'Sergipe', 'Tocantins']

# %%
lista_federacao.append('TipsLand') #Adicionando um novo estado à lista como ultimo elemento.

# %%
print(lista_federacao)
# Out:
# ['Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito Federal', 'Espírito Santo', 'Goiás', 'Maranhão', 'Mato Grosso', 'Mato Grosso do Sul', 'Minas Gerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio de Janeiro', 'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondônia', 'Roraima', 'Santa Catarina', 'São Paulo', 'Sergipe', 'Tocantins', 'TipsLand']

# %%
lista_federacao.extend(['Judá', 'Jerusalém']) #Adicionando mais de um estado à lista.

# %%
print(lista_federacao)
# Out:
# ['Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito Federal', 'Espírito Santo', 'Goiás', 'Maranhão', 'Mato Grosso', 'Mato Grosso do Sul', 'Minas Gerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio de Janeiro', 'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondônia', 'Roraima', 'Santa Catarina', 'São Paulo', 'Sergipe', 'Tocantins', 'TipsLand', 'Judá', 'Jerusalém']
