# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('### Bem-vindo à busca do tesouro escondido! ###')
print('Sua missão é encontrar o tesouro!')

escolha1 = input('''Você está em uma encruzilhada, para onde deseja ir? "Direita" ou "Esquerda"?''').lower()
if escolha1 == 'esquerda':
    escolha2 = input('''Você chegou a opção de nadar ou andar. O que deseja?''').lower()
    if escolha2 == 'andar':
        escolha3 = input('''Você andou até encontrar três portas: "vermelha", "amarela" ou "azul"! Escolha uma!''').lower()
        if escolha3 == 'amarela':
            print('Parabéns! Você encontrou o tesouro escondido!')
        elif escolha3 == "vermelha":
            print('Você encontrou uma sala cheia de gás venenoso! Game Over!')
        elif escolha3 == 'azul':
            print('Você encontrou uma sala com serpentes peçonhentas! Game Over! ')
    else:
        print('Você tentou nadar e morreu afogado! Game Over!')
else: 
    print('Você caiu em um buraco sem fundo! Game Over!')
# Out:
# ### Bem-vindo à busca do tesouro escondido! ###
# Sua missão é encontrar o tesouro!
# Parabéns! Você encontrou o tesouro escondido!

# %% [markdown]
# CORREÇÃO:

# %%
print('Bem-vindo(a) à Ilha do tesouro perdido!')
print('Sua missão é encontrar o tesouro!')

escolha1 = input('''Você está em uma encruzilhada, para onde deseja ir? Digite "esquerda" ou "direita":''').lower()
if escolha1 == 'esquerda':
    escolha2 = input('Você deseja nadar ou esperar?').lower()
    if escolha2 == 'nadar':
        escolha3 = input('Qual porta você escolhe? Digite "vermelha", "amarela" ou "azul": ').lower()
        if escolha3 == 'vermelha':
            print('Game Over!')
        elif escolha3 == 'amarela':
            print('Você achou o tesouro! Parabéns!')
        elif escolha3 == 'azul':
            print ('Game Over!')
    else:
        print('Game Over!')
else:
    print('Game Over!')
# Out:
# Bem-vindo(a) à Ilha do tesouro perdido!
# Sua missão é encontrar o tesouro!
# Você achou o tesouro! Parab´nes!
