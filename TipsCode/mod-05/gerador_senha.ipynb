# %% [markdown]
# ### Gerador de senha forte de 8 caracteres

# %%
print('### Seja bem-vindo ao poderoso gerador de senha! ###')

import random

letras = input('Digite a quantidade de letras que você deseja para sua senha: ')
simbolos = input('Digite a quantidade de símbolos que você deseja para sua senha: ')
numeros = input('Digite a quantidade de números que você deseja para sua senha: ')
# Out:
# ### Seja bem-vindo ao poderoso gerador de senha! ###
