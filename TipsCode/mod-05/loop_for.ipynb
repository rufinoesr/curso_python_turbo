# %%
frutas = ['Banana', 'Maçã', 'Uva', 'Laranja', 'Goiaba'] #Lista de frutas.

for fruta in frutas:
    print(fruta) #Imprimindo cada fruta da lista de frutas.
# Out:
# Banana
# Maçã
# Uva
# Laranja
# Goiaba
