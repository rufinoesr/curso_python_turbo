# %% [markdown]
# Variáveis

# %%
nome = input('Qual é o seu nome? ')
print(nome)
# Out:
# Edilson

# %% [markdown]
# A função len() só funciona com STRINGS, não funcionam com números.

# %%
name = 'Jesus Cristo'
lenght = len(name)
print(lenght)
# Out:
# 12

# %% [markdown]
# Nomeação em variáveis

# %%
use_name = 'Jesus Cristo'
lenght = len(use_name) # calcula o número de caracteres na string.
print(lenght)
# Out:
# 12
