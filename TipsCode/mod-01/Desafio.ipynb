# %% [markdown]
# Criando meu primeiro programa Python.

# %%
print('Bem-vindo ao programa de contagem de caracteres!')

full_name = input('Qual é o seu nome completo?' )

lenght = len(full_name)

print(full_name)
print(f'Seu nome completo tem {lenght} caracteres.')
# Out:
# Bem-vindo ao programa de contagem de caracteres!
# Edilson da Silva Rufino
# Seu nome completo tem 23 caracteres.
