# %%
'spam eggs'
# Out:
# 'spam eggs'

# %%
'd\'água'
# Out:
# "d'água"

# %%
'Ed + il + son'
# Out:
# 'Ed + il + son'

# %%
'Ed' + 'il' + 'son'
# Out:
# 'Edilson'

# %%
'Py' 'thon'
# Out:
# 'Python'

# %%
Texto = ('Este é um texto longo que abrange várias linhas. ')

Texto
# Out:
# 'Este é um texto longo que abrange várias linhas. '

# %%
prefixo = 'Py'

prefixo + 'thon'
# Out:
# 'Python'

# %%
palavra = 'Python'

palavra[-2]
# Out:
# 'o'

# %%
palavra[1:-2]
# Out:
# 'yth'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# strings, que são imutáveis
